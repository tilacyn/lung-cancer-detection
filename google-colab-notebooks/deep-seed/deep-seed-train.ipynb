# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pydicom
# !pip install SimpleITK
# Out:
# ...
#      |████████████████████████████████| 35.5MB 89kB/s
# ...
#      |████████████████████████████████| 42.5MB 72kB/s
# ...

# %%
import os
from os.path import join as opjoin
base_path = '/content/drive/My Drive/DeepSEED-3D-ConvNets-for-Pulmonary-Nodule-Detection'
data_path = '/content/drive/My Drive/dsb2018_topcoders/data'
luna_path = opjoin(base_path, 'luna_detector')

# %%
os.chdir(base_path)
# !git pull
# Out:
# Already up to date.

# %%
os.chdir(luna_path)
! CUDA_VISIBLE_DEVICES=0,1,2,3,4 python train_detector_se.py --test 0 -b 4 --save-dir 'test_results/with_augmented_128_cv_4' --mode theirs --epochs 105 --dataset_split 4 --with_augmented 1 --resume 'with_augmented_128_cv_4/detector_038.ckpt'
# Out:
# creating model
# FOCAL LOSS 2 0.5
# created model
# => loading checkpoint 'with_augmented_128_cv_4/detector_038.ckpt'
# using gpu 0
# len lun train 800
# len idcs  767
# augmented idcs number  373
# augmented labels
# [array([[148.8212421 ,  98.01444622, 104.47241272,  14.31390685],
#        [ 90.1141511 ,  53.82973613,  82.4173147 ,   8.22221772],
#        [139.5727821 ,  78.2041335 , 268.2663418 ,   4.77182652]]), array([[135.9560028 , 181.44187934, 227.84731599,   8.48983727]]), array([[ 56.2851794 ,  70.61886786, 269.637574  ,  20.38922514]]), array([[201.5361701 , 209.7617849 ,  64.217876  ,  10.05662598]]), array([[269.27631567, 122.68208306, 106.47778904,  22.88079244]]), array([[195.8971628 ,  86.56574893, 244.78026471,  22.03891888]]), array([[ 77.0072107 , 174.89230782,  92.39520384,   8.7666574 ],
# ...

# %%
os.chdir(luna_path)
from path import augmented_data_path, ctgan_base_path, augmented_prp, preprocess_result_path, mhd_src_path
from augmentation.service import AugmentationService

aug_service = AugmentationService(augmented_data_path)
aug_service.preprocess_augmented_data()
# Out:
# skipping 803
# skipping 802
# skipping 102
# skipping 115
# skipping 154
# skipping 100
# skipping 101
# skipping 103
# skipping 105
# skipping 107
# skipping 108
# skipping 114
# skipping 117
# skipping 119
# skipping 120
# skipping 121
# skipping 122
# skipping 123
# skipping 125
# skipping 126
# skipping 135
# skipping 138
# skipping 139
# skipping 145
# skipping 147
# skipping 146
# skipping 148
# skipping 150
# skipping 155
# skipping 156
# skipping 157
# skipping 158
# skipping 159
# skipping 160
# skipping 161
# skipping 167
# skipping 170
# skipping 172
# skipping 176
# skipping 178
# skipping 179
# skipping 181
# skipping 180
# skipping 183
# skipping 185
# skipping 187
# skipping 188
# skipping 190
# sliceim  (313, 512, 512)
# origin  (3,)
# spacing  (3,)
# isflip  False
# Mask  (269, 512, 512)
# name  191
# enter save npy
# /content/drive/My Drive/DeepSEED-3D-ConvNets-for-Pulmonary-Nodule-Detection/data/augmented-preprocess-result-path
# skipping 192
# skipping 193
# ...
